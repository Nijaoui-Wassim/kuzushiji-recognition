# %% [markdown]
# # kuzushiji-recognition_preprocessing

# %% [markdown]
# ### importing libraries

# %%
# %matplotlib inline

#from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import ImageFont, ImageDraw, Image
import pandas as pd
import numpy as np
import pickle
import cv2
import os

# %% [markdown]
# ### importing dataset

# %%
df = pd.read_csv("train.csv")
df_test = pd.read_csv("sample_submission.csv")
df_decode = pd.read_csv("unicode_translation.csv")
#profile = ProfileReport(df, title="Pandas Profiling Report")
X = df.iloc[:,:].values
df.head(5)
# Out:
#             image_id                                             labels
# 0  100241706_00004_2  U+306F 1231 3465 133 53 U+304C 275 1652 84 69 ...
# 1  100241706_00005_1  U+306F 1087 2018 103 65 U+304B 1456 1832 40 73...
# 2  100241706_00005_2  U+306F 572 1376 125 57 U+306E 1551 2080 69 68 ...
# 3  100241706_00006_1  U+3082 1455 3009 65 44 U+516B 1654 1528 141 75...
# 4  100241706_00007_2  U+309D 1201 2949 27 33 U+309D 1196 1539 27 36 ...

# %%
df_test.head(5)
# Out:
#         image_id                 labels   Useage
# 0  test_001c37e2  U+003F 1 1 U+FF2F 2 2  Private
# 1  test_003aa33a  U+003F 1 1 U+FF2F 2 2   Public
# 2  test_00665e33  U+003F 1 1 U+FF2F 2 2  Private
# 3  test_0082d2cd  U+003F 1 1 U+FF2F 2 2  Private
# 4  test_0086f578  U+003F 1 1 U+FF2F 2 2  Private

# %%
df_decode.head(5)
# Out:
#   Unicode char
# 0  U+0031    1
# 1  U+0032    2
# 2  U+0034    4
# 3  U+0036    6
# 4  U+0039    9

# %% [markdown]
# ### visualizing a random label

# %%
lab = df["labels"][0]
print(lab)
# Out:
# U+306F 1231 3465 133 53 U+304C 275 1652 84 69 U+3044 1495 1218 143 69 U+3051 220 3331 53 91 U+306B 911 1452 61 92 U+306B 927 3445 71 92 U+306E 904 2879 95 92 U+5DE5 1168 1396 187 95 U+3053 289 3166 69 97 U+4E09 897 3034 121 107 U+306E 547 1912 141 108 U+3084 1489 2675 151 109 U+3068 1561 2979 55 116 U+5DF1 1513 2500 127 117 U+3082 1213 1523 72 119 U+3055 1219 3266 95 124 U+306E 259 2230 68 125 U+306E 1184 2423 169 125 U+4E16 849 2236 163 127 U+7D30 1144 1212 200 128 U+305D 316 3287 57 133 U+4EBA 217 2044 183 135 U+3051 277 2974 112 137 U+308C 201 3423 181 137 U+3060 243 2830 159 143 U+5F37 1479 2034 163 145 U+306E 1497 1567 123 152 U+305F 1164 952 145 153 U+3066 552 1199 97 155 U+4FF3 537 2095 176 155 U+6839 203 1439 184 156 U+304B 1188 2606 156 157 U+8AE7 549 2328 156 159 U+308C 1495 2784 168 159 U+5B50 891 1255 100 164 U+3092 584 2546 117 164 U+53CA 849 1588 151 164 U+8005 1192 2198 133 169 U+305A 889 1763 103 171 U+907F 513 945 181 171 U+6B63 539 1439 136 172 U+6587 192 2382 216 1
# ...

# %%
def whiten_img_edges(img, n_rows):
    #reshaping img: from 3868, 2380 , 3
    height = img.shape[0]
    width  = img.shape[1]
    ch_num = img.shape[2]
    img= img.reshape(height*width, img.shape[2])
    filling = [255, 255, 255]
    #taking care of the upper edge
    for i in range(width*n_rows):
        img[i] = filling
    #taking care of the lower edge
    for i in range(height*(width-n_rows),width*height):
        img[i] = filling
    #taking care of the left and right edge
    for i in range(0,width*height,width):
        #left side
        img[i:i+n_rows] = [filling for j in range(n_rows)]
        #right side
        img[i+width-n_rows:i+width] = [filling for j in range(n_rows)]
    img = img.reshape(height, width, ch_num)
    return img

def break_down_label(y):
    my_label = df["labels"][y].split()
    letters, x_coord, y_coord, width, heights = [], [], [], [], []
    for i in range(0,len(my_label),5):
        try:
            letters.append(my_label[i  ] + " ")
            x_coord.append(my_label[i+1] + " ")
            y_coord.append(my_label[i+2] + " ")
            width.append(my_label[i+3] + " ")
            heights.append(my_label[i+4] + " ")
        except Exception as e :
            print(e)
            #pass
    return letters, x_coord, y_coord, width, heights

def draw_rect_img(img, y, thickness = 3, color = (255,0,0)):
    letters, x_coord, y_coord, width, heights = break_down_label(y)
    for i in range(len(width)):
        start_point = (int(x_coord[i]), int(y_coord[i]))
        end_point   = (int(width[i]) + int(x_coord[i]), int(heights[i]) + int(y_coord[i]))
        img = cv2.rectangle(img ,start_point, end_point , color, thickness)
    return img
    
def get_rect_img(img, y, counted_elements, imgs = [], y_s = [], minimum_recc = 100):
    letters, x_coord, y_coord, width, heights = break_down_label(y)
    num_errors = 0
    for i in range(len(width)):
        try:
            start_point = (int(x_coord[i]), int(y_coord[i]))
            end_point   = (int(width[i]) + int(x_coord[i]), int(heights[i]) + int(y_coord[i]))
            #img = cv2.rectangle(img ,start_point, end_point , color, thickness)
            #crop_img = img[y:y+h, x:x+w]
            crop_img = img[int(y_coord[i]):int(y_coord[i])+int(heights[i]), int(x_coord[i]):int(x_coord[i]) +int(width[i]) ]
            crop_img = fix_img_size(crop_img)
            if counted_elements != 0:
                if (counted_elements[letters[i].replace(" ","")] > minimum_recc):
                    y_s.append(letters[i].replace(" ",""))
                else:
                    y_s.append("other")
            imgs.append(crop_img)
        except:
            num_errors +=1
    if num_errors != 0:
        print("number of errors for this img: ", num_errors)
    return imgs, y_s

def draw_labels_img(img, y, thickness = 3, color = (155,0,155)):
    fontpath = "./simsun.ttc"
    font = ImageFont.truetype(fontpath, 52)
    letters, x_coord, y_coord, width, heights = break_down_label(y)
    for i in range(len(width)):
        img_pil = Image.fromarray(img)
        draw = ImageDraw.Draw(img_pil)
        draw.text((int(x_coord[i])-100, int(y_coord[i])),  transform(letters[i], df_decode), font = font, fill = color)#transform(letters[i], df_decode)
        img = np.array(img_pil)
        img = img[:, :, ::-1].copy() 
    return img

def update_counter(counter, i, df_decode):
    X_decode = df_decode.iloc[:,:].values
    letters, _, _, _, _ = break_down_label(i)
    for j in range(len(letters)):
        index = np.where(X_decode[:,0] == letters[j].strip())
        counter[index] += 1
    return counter
        
    #my_label = df["labels"][i].split()
    return counter

def transform(letter,df_decode):
    try:
        letter = letter.strip()
        X_decode = df_decode.iloc[:,:].values
        #unicodes = X_decode[:,0].tolist()
        #index = unicodes.index(letter)
        index = np.where(X_decode[:,0] == letter)
        decoded_letter = X_decode[index,1][0][0]
    except:
        decoded_letter = "ERROR"
    return decoded_letter

def to_unicode(letter,df_decode):
    try:
        letter = letter.strip()
        X_decode = df_decode.iloc[:,:].values
        #unicodes = X_decode[:,0].tolist()
        #index = unicodes.index(letter)
        index = np.where(X_decode[:,1] == letter)
        unicoded_letter = X_decode[index,0][0][0]
    except Exception as e:
        print(e)
        unicoded_letter = "ERROR"
    return unicoded_letter

letters, x_coord, y_coord, width, heights = break_down_label(0)

for i in range(10): #len(letters)
    print("Letter (Unicode): "+letters[i] + "Which is : " + transform(letters[i], df_decode))
    print("Coordinates are : ("+x_coord[i] + ", "+y_coord[i] + ", "+width[i] + ", "+heights[i] + ")\n\n " )
# Out:
# Letter (Unicode): U+306F Which is : は
# Coordinates are : (1231 , 3465 , 133 , 53 )
#
#
# Letter (Unicode): U+304C Which is : が
# Coordinates are : (275 , 1652 , 84 , 69 )
#
#
# Letter (Unicode): U+3044 Which is : い
# Coordinates are : (1495 , 1218 , 143 , 69 )
#
#
# Letter (Unicode): U+3051 Which is : け
# Coordinates are : (220 , 3331 , 53 , 91 )
#
#
# Letter (Unicode): U+306B Which is : に
# Coordinates are : (911 , 1452 , 61 , 92 )
#
#
# Letter (Unicode): U+306B Which is : に
# Coordinates are : (927 , 3445 , 71 , 92 )
#
#
# Letter (Unicode): U+306E Which is : の
# Coordinates are : (904 , 2879 , 95 , 92 )
#
#
# Letter (Unicode): U+5DE5 Which is : 工
# Coordinates are : (1168 , 1396 , 187 , 95 )
#
#
# Letter (Unicode): U+3053 Which is : こ
# Coordinates are : (289 , 3166 , 69 , 97 )
#
#
# Letter (Unicode): U+4E09 Which is : 三
# Coordinates are : (897 , 3034 , 121 , 107 )

# %% [markdown]
# ### visualizing few examples

# %%
def convert_pic(sample_id):    
    image_file = Image.open("train_images/" + sample_id + ".jpg") # open colour image
    image_file = prepare_img(random_img)
    #image_file = image_file.convert('1') # convert image to black and white
    image_file.save("new_train/"+sample_id+".jpg")
    
def prepare_image(df, num_imgs,proc = False):
    imgs, labels = [], []
    for i in range(num_imgs):
        index = i*15
        sample_id = df["image_id"][index]
        if proc == False:
            random_img_path ="train_images/" + sample_id + ".jpg"
        else:
            random_img_path ="train_images/" + sample_id + ".jpg"
        #reading the img
        random_img = cv2.imread(random_img_path)
        if proc:
            random_img = prepare_img(random_img)
        else:
            #converting the img to an RGB colored img
            random_img = cv2.cvtColor(random_img, cv2.COLOR_BGR2RGB)
        imgs.append(random_img)
        labels.append(index)
    return imgs, labels

def unpack(*my_list):
    for item in my_list:
        return item
    
def fix_img_size(img, s = 64):
    top, bottom, left, right = 0, 0, 0, 0
    if img.shape[0] < s:
        if ((s-img.shape[0])%2==0):
            left, right = int((s-img.shape[0])/2), int((s-img.shape[0])/2)
        else:
            left, right = int((s-img.shape[0])/2), int((s-img.shape[0])/2)+1
    #else:
    if img.shape[1] < s:
        if ((s-img.shape[0])%2==0):
            top, bottom = int((s-img.shape[1])/2), int((s-img.shape[1])/2)
        else:
            top, bottom = int((s-img.shape[1])/2), int((s-img.shape[1])/2)+1
    #else:
    #img = cv2.copyMakeBorder( img, top, bottom, left, right, borderType = cv2.BORDER_CONSTANT, value = (255,255,255))
    img = cv2.resize(img, (s, s), interpolation = cv2.INTER_AREA)
    return img


def prepare_img(Image): 
    im_color = Image
    im_gray = cv2.cvtColor(im_color, cv2.COLOR_BGR2GRAY)
    _, mask = cv2.threshold(im_gray, thresh=150, maxval=255, type=cv2.THRESH_BINARY)
    im_thresh_gray = cv2.bitwise_and(im_gray, mask)
    mask3 = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)  # 3 channel mask
    return mask3 #im_thresh_gray

# %%
fig = plt.figure(figsize=(15,15))
imgs, labels = prepare_image(df, 4)
img_1, img_2, img_3, img_4 = unpack(imgs)

# Plot imgs
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img_1)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(img_2)
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img_3)
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(img_4)

# %% [markdown]
# # Data Preprocessing

# %%
fig = plt.figure(figsize=(15,15))
imgs, labels = prepare_image(df, 4, True)
img_1, img_2, img_3, img_4 = unpack(imgs)

# Plot imgs
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img_1)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(img_2)
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img_3)
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(img_4)

# %%
fig = plt.figure(figsize=(15,15))
imgs, labels = prepare_image(df, 4, True)
img_1, img_2, img_3, img_4 = unpack(imgs)

img_1 = whiten_img_edges(img_1, 120)
img_2 = whiten_img_edges(img_2, 120)
img_3 = whiten_img_edges(img_3, 140)
img_4 = whiten_img_edges(img_4, 140)

ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img_1)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(img_2)
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img_3)
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(img_4)

# %% [markdown]
# ### Preparing the train set

# %%
for i in tqdm(range(len(df["image_id"]))):
    img_path ="train_images/" + df["image_id"][i] + ".jpg"
    img = cv2.imread(img_path)
    img = prepare_img(img)
    img = whiten_img_edges(img, 120)
    cv2.imwrite("train_images_bw/"+df["image_id"][i] + ".jpg", img) 


#commented out because it needs to be excuted only once
# Out:
#  32%|████████████████████████▋                                                   | 1170/3605 [47:54<1:27:37,  2.16s/it]

# %% [markdown]
# ### Preparing the test set

# %%
for i in tqdm(range(len(df_test["image_id"]))):
    img_path ="test_images/" + df_test["image_id"][i] + ".jpg"
    img = cv2.imread(img_path)
    img = prepare_img(img)
    cv2.imwrite("test_images_bw/"+df_test["image_id"][i] + ".jpg", img)

# %% [markdown]
# ## Get individual caracteres and labeling them

# %%
fig = plt.figure(figsize=(15,15))
imgs, labels = prepare_image(df, 2, True)
img_1, img_2 = unpack(imgs)
y_1, y_2 = unpack(labels)
img_2 = draw_rect_img(img_2, y_2, 3)
img_2 = draw_labels_img(img_2, y_2, 3)
img_2 = whiten_img_edges(img_2, 100)
plt.imshow(img_2)

# %% [markdown]
# ## Cropping characters

# %%
fig = plt.figure(figsize=(5,5))
imgs, labels = prepare_image(df, 2, True)
img_1, img_2 = unpack(imgs)
y_1, y_2 = unpack(labels)
img_1_chars, _ = get_rect_img(img_2, y_2,0)
# Plot imgs
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img_1_chars[0])
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(img_1_chars[1])
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img_1_chars[2])
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(img_1_chars[3])

# %% [markdown]
# ## Normlizing the shapes to 64 x 64 imgs

# %%
fig = plt.figure(figsize=(7,7))
imgs, labels = prepare_image(df, 2, True)
img_1, img_2 = unpack(imgs)
y_1, y_2 = unpack(labels)
img_1_chars, _ = get_rect_img(img_2, y_2, 0)
# Plot imgs
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(fix_img_size(img_1_chars[0]))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(fix_img_size(img_1_chars[1]))
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(fix_img_size(img_1_chars[2]))
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(fix_img_size(img_1_chars[3]))

#fix_img_size(img)

# %% [markdown]
# ## Getting word count and analyzing data destribution

# %%
counter = np.zeros((df_decode.shape[0],), dtype=int)
for i in range(len(df["image_id"])):
    counter = update_counter(counter, i, df_decode)
    if i%400 == 0:
        print((i/40)+9, " %")
print("Done for original dataset")
# Out:
# 9.0  %
# 19.0  %
# 29.0  %
# 39.0  %
# 49.0  %
# 59.0  %
# 69.0  %
# 79.0  %
# 89.0  %
# 99.0  %
# Done for original dataset

# %%
# to convert lists to dictionary 
counter_orig = counter
X_decode = df_decode.iloc[:,0].values
counted_elements = {X_decode[i]: counter[i] for i in range(len(counter))} 
print(counted_elements['U+242CE'])
# Out:
# 2

# %%
print("The number of caracters is : ", counter.sum())
# Number of characters that showed in all pictures:
print("The number of elements that showed up 0 time:", np.count_nonzero(counter_orig==0))
print("The number of elements that showed up 1 time:", np.count_nonzero(counter_orig==1))
print("The number of elements that showed up less than 10 times:", np.count_nonzero(counter_orig<10))
print("The number of elements that showed up less than 50 times:", np.count_nonzero(counter_orig<50))
print("\nThe number of elements that showed up MORE than 100 times:", np.count_nonzero(counter_orig>100))
print("The number of elements that showed up MORE than 1000 times:", np.count_nonzero(counter_orig>1000))
# Out:
# The number of caracters is :  683442
# The number of elements that showed up 0 time: 575
# The number of elements that showed up 1 time: 788
# The number of elements that showed up less than 10 times: 2753
# The number of elements that showed up less than 50 times: 3795
#
# The number of elements that showed up MORE than 100 times: 621
# The number of elements that showed up MORE than 1000 times: 99

# %%
fig = plt.figure(figsize=(10,5))
x_axis = [i for i in range(len(counter_orig))]
plt.bar(x_axis, counter_orig)
plt.xlabel("Number of unique words")
plt.ylabel("Frequency of each words")
fig.suptitle('Letters Count')
# Out:
# Text(0.5, 0.98, 'Letters Count')

# %%
# Sorting the counted elements in descending order
counter[::-1].sort()
fig = plt.figure(figsize=(10,5))
plt.bar(x_axis, counter)
plt.xlabel("Number of unique words")
plt.ylabel("Frequency of each words")
fig.suptitle('Letters Count')
# Out:
# Text(0.5, 0.98, 'Letters Count')

# %%
# Plotting only the elements that showed up more than 100 times:
x_axis = [i for i in range(621)]
fig = plt.figure(figsize=(10,5))
plt.bar(x_axis, counter[:621])
plt.xlabel("Number of unique words")
plt.ylabel("Frequency of each words")
fig.suptitle('Letters Count')
# Out:
# Text(0.5, 0.98, 'Letters Count')

# %%
# Plotting only the elements that showed up more than 100 times: in terms of percentage 
fig = plt.figure(figsize=(10,5))
#percentgs = [(counter[i]/counter[:99].sum())*100 for i in range(99)]
plt.bar(x_axis[:99], counter[:99])
plt.xlabel("Number of unique words")
plt.ylabel("Frequency of each words")
fig.suptitle('Letters Count in % of the top 1000 most reccurent words')
# Out:
# Text(0.5, 0.98, 'Letters Count in % of the top 1000 most reccurent words')

# %%
# Therefore we don't have equal samples to train the model and 575 label did not appear at all in the training data
# The graph follows the ZIPF shape,

# %% [markdown]
# ## Prepare X and y

# %%
X, y = [], [] # For words that accured more than 100 times where X contains caracters imgs and y contains labels

for i in range(len(df["image_id"])):
    img_path ="train_images_bw/" + df["image_id"][i] + ".jpg"
    img = cv2.imread(img_path)
    X,y = get_rect_img(img, i, counted_elements, X, y)
    if i%400 == 0:
        print((i/40)+9, " %")
        pickle.dump( X, open( "chars/X_"+str(int((i/40)))+".p", "wb" ) )
        pickle.dump( y, open( "chars/y_"+str(int((i/40)))+".p", "wb" ) )
        X,y = [],[]
pickle.dump( X, open( "chars/X_final.p", "wb" ) )
pickle.dump( y, open( "chars/y_final.p", "wb" ) )

print("Done")
# Out:
# 9.0  %
# 19.0  %
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  1
# 29.0  %
# number of errors for this img:  2
# 39.0  %
# number of errors for this img:  2
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  3
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  2
# number of errors for this img:  1
# number of errors for this img:  1
# number of errors for this img:  2
# 49.0  %
# 59.0  %
# 69.0  %
# 79.0  %
# 89.0  %
# 99.0  %
# Done

# %%
print(len(y))
y[50:60]
# X_1 = pickle.load( open( "save.p", "rb" ) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-928c60034b3e> in <module>
# ----> 1 print(len(y))
#       2 y[50:60]
#       3 # X_1 = pickle.load( open( "save.p", "rb" ) )
#
# NameError: name 'y' is not defined

# %%
print(len(X))
X[1]
# Out:
# 722
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[  0,   1,   4],
#         [  0,   0,   3],
#         [  0,   2,   3],
#         ...,
#         [  0,   0,   1],
#         [ 12,  14,  15],
#         [ 96,  99, 100]],
#
#        [[ 23,  25,  29],
#         [  0,   1,   3],
#         [  0,   1,   2],
#         ...,
#         [  3,   4,   5],
#         [ 39,  42,  43],
#         [129, 133, 134]],
#
#        [[ 55,  58,  62],
#         [  0,   1,   3],
# ...

# %% [markdown]
# # Importing data from an external dataset

# %%
letter = "難"
lt = to_unicode(letter,df_decode)
print(lt)
lt = "U+4E2D"
letter_path = 'kmnist-master/kkanji2/'+ lt + "/."
number_of_files = len([name for name in os.listdir(letter_path) ])
print(number_of_files)
# Out:
# U+FA68
# 789

# %%
ct = 0
def external_data_counter(counter_external, letter, i):
    global ct
    try: # Kuzushiji Recognition\kmnist-master\kkanji2\U+4E2D
        letter_path = 'kmnist-master/kkanji2/'+ to_unicode(letter,df_decode) + "/."
        number_of_files = len([name for name in os.listdir(letter_path)])
        counter_external[i] += number_of_files
        print (number_of_files)
        ct+=1
        return counter_external
    except Exception as e:
        return counter_external

                                                                  
counter_external = counter_orig #np.zeros((df_decode.shape[0],), dtype=int)        X_decode[i]: counter[i]
for i in range(len(X_decode)):
    counter_external = external_data_counter(counter_external, letter, i)
    if i%320 == 0:
        print((i/50)+10, " %")
print("Done")
print(counter_external)
print("The number of added letters is : ",ct)
print("Therefore, it was not a useful dataset.")
# Out:
# 10.0  %
# 16.4  %
# 22.8  %
# 29.2  %
# 35.6  %
# 42.0  %
# 48.4  %
# 54.8  %
# 61.2  %
# 67.6  %
# 74.0  %
# 80.4  %
# 86.8  %
# 93.2  %
# 99.6  %
# Done
# [0 0 0 ... 7 1 1]
# The number of added letters is :  0
# Therefore, it was not a useful dataset.

# %% [markdown]
# # Generating data

# %% [markdown]
# ### Using Rotations and transition

# %%
import tensorflow as tf
from tensorflow.keras import layers
from skimage import io, color

IMG_SIZE = 180

resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255)
])

data_augmentation = tf.keras.Sequential([
  #layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.05),
  layers.experimental.preprocessing.RandomCrop(64, 64)
])

# %%
X_f = []
y_f = []
for i in range(1):
    X = pickle.load( open( "chars/X_"+str(i)+"0.p", "rb" ) )
    y = pickle.load( open( "chars/y_"+str(i)+"0.p", "rb" ) )
    X = np.array(X)
    y = np.array(y)
    for i in range(len(X)):
        img = X[i]
        #img = color.rgb2gray(img)
        X_f.append(img)
        y_f.append(y[i])
    del X, y
X = np.array(X_f)
y = np.array(y_f)
del X_f, y_f

#image = tf.expand_dims(X[0], 0)

plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(image)
    print(len(augmented_image))
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_image[0])
    plt.axis("off")
    
# number of pictures now = n * 9
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# ### Using autoencoders
